# %%
import os
import cv2
import glob as gb
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# 2022-04-18 00:39:50.708063: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
gpu_device = tf.config.experimental.list_physical_devices('GPU')
print(f"Number of GPU = {len(gpu_device)}")
tf.config.experimental.set_memory_growth(gpu_device[0], True)
# Out:
# Number of GPU = 1
# 2022-04-18 00:39:57.184751: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-04-18 00:39:57.185711: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-04-18 00:39:57.276890: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-18 00:39:57.277430: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 2060 computeCapability: 7.5
# coreClock: 1.2GHz coreCount: 30 deviceMemorySize: 5.79GiB deviceMemoryBandwidth: 312.97GiB/s
# 2022-04-18 00:39:57.277500: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-04-18 00:39:57.577437: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-04-18 00:39:57.577631: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-04-18 00:39:57.728867: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-04-18 00:39:57.781114: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-04-18 00:39:58.145552: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-04-18 00:39:58.233622: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-04-18 00:39:58.801766: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-04-18 00:39:58.802183: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-18 00:39:58.803846: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-18 00:39:58.805443: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0

# %%
SEED = 1000
IMG_SIZE = 224
BATCH_SIZE = 16

TRAIN_DIR = '/home/dev/Documents/datasets/face'

# %%
class_names = []
class_count = []
train_examples = 0
for f in os.listdir(TRAIN_DIR):
  files = gb.glob(pathname=str(TRAIN_DIR + "//" + f + "/*"))
  class_names.append(f)
  class_count.append(len(files))
  train_examples += len(files)
plt.figure(figsize=(20,5))
sns.barplot(x=class_names, y=class_count)
plt.show()

# %%
train_gen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range = 0.3,
    horizontal_flip=True,
    validation_split=0.2,
    preprocessing_function=tf.keras.applications.vgg16.preprocess_input,
    dtype=tf.float32
)

# %%
test_gen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.vgg16.preprocess_input,
    dtype=tf.float32
)

# %%
train_batch = train_gen.flow_from_directory(
    directory=TRAIN_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    subset='training',
    class_mode = 'sparse',
    seed=SEED
)
# Out:
# Found 344 images belonging to 43 classes.

# %%
valid_batch = train_gen.flow_from_directory(
    directory=TRAIN_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    subset='validation',
    class_mode = 'sparse',
    seed=SEED
)
# Out:
# Found 86 images belonging to 43 classes.

# %%
imgs, labels = next(train_batch)
i=0
plt.figure(figsize=(20,5))
for img,label in zip(imgs,labels):
  plt.subplot(4,10,i+1)
  plt.imshow(img.astype('uint8'))
  plt.xlabel(class_names[label.astype('int32')])
  plt.xticks([])
  plt.yticks([])
  i+=1
  if i==30:
    break
plt.tight_layout()
plt.show()

# %%
IMG_SHAPE = (IMG_SIZE,IMG_SIZE) + (3,)
base_model = tf.keras.applications.VGG16(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
# Out:
# 2022-04-18 00:40:03.022637: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-18 00:40:03.024479: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-18 00:40:03.026208: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 2060 computeCapability: 7.5
# coreClock: 1.2GHz coreCount: 30 deviceMemorySize: 5.79GiB deviceMemoryBandwidth: 312.97GiB/s
# 2022-04-18 00:40:03.026382: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-04-18 00:40:03.026501: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-04-18 00:40:03.026586: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-04-18 00:40:03.026657: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-04-18 00:40:03.026727: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-04-18 00:40:03.026798: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-04-18 00:40:03.026868: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-04-18 00:40:03.026940: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-04-18 00:40:03.027193: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-18 00:40:03.028882: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-18 00:40:03.030046: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-04-18 00:40:03.039604: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-04-18 00:40:09.286200: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-04-18 00:40:09.286261: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-04-18 00:40:09.286281: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-04-18 00:40:09.303040: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-18 00:40:09.304636: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-18 00:40:09.305961: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-18 00:40:09.307212: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 5291 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2060, pci bus id: 0000:01:00.0, compute capability: 7.5)
# 2022-04-18 00:40:09.335752: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set

# %%
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
base_model.trainable = False

# %%
inputs = tf.keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = base_model(inputs, training=False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)

x = tf.keras.layers.Dense(512, activation='relu')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dropout(0.4)(x)

x = tf.keras.layers.Dense(256, activation='relu')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dropout(0.4)(x)

x = tf.keras.layers.Dense(128, activation='relu')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dropout(0.2)(x)

outputs = tf.keras.layers.Dense(43, activation='softmax')(x)
model = tf.keras.Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               262656
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 43)                5547
# =================================================================
# Total params: 15,150,699
# Trainable params: 434,219
# Non-trainable params: 14,716,480
# _________________________________________________________________

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3), 
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy']
)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.00001, verbose=1)

# %%
h = model.fit(train_batch, 
              epochs=50,
              steps_per_epoch = 344 // BATCH_SIZE,
              validation_data = valid_batch,
              validation_steps = 86 // BATCH_SIZE,
              callbacks=[reduce_lr]
             )
# Out:
# 2022-04-18 00:40:13.728309: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-04-18 00:40:13.766849: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2599990000 Hz
# Epoch 1/50
# 2022-04-18 00:40:14.976857: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-04-18 00:40:17.048114: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-04-18 00:40:24.196707: W tensorflow/stream_executor/gpu/asm_compiler.cc:63] Running ptxas --version returned 256
# 2022-04-18 00:40:24.236989: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: ptxas exited with non-zero error code 256, output:
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2022-04-18 00:40:25.068623: W tensorflow/core/common_runtime/bfc_allocator.cc:314] Garbage collection: deallocate free memory regions (i.e., allocations) so that we can re-allocate a larger region to avoid OOM due to memory fragmentation. If you see this message frequently, you are running near the threshold of the available device memory and re-allocation may incur great performance overhead. You may try smaller batch sizes to observe the performance impact. Set TF_ENABLE_GPU_GARBAGE_COLLECTION=false if you'd like to disable this feature.
# 21/21 [==============================] - 58s 2s/step - loss: 4.6810 - accuracy: 0.0353 - val_loss: 4.3860 - val_accuracy: 0.0250
# Epoch 2/50
# 21/21 [==============================] - 28s 1s/step - loss: 3.7120 - accuracy: 0.0793 - val_loss: 3.6106 - val_accuracy: 0.1375
# Epoch 3/50
# 21/21 [==============================] - 27s 1s/step - loss: 3.1530 - accuracy: 0.2079 - val_loss: 3.1184 - val_accuracy: 0.2000
# Epoch 4/50
# 21/21 [==============================] - 27s 1s/step - loss: 2.8820 - accuracy: 0.2639 - val_loss: 2.7817 - val_accuracy: 0.3000
# Epoch 5/50
# 21/21 [==============================] - 26s 1s/step - loss: 2.4857 - accuracy: 0.3739 - val_loss: 2.5291 - val_accuracy: 0.3125
# Epoch 6/50
# 21/21 [==============================] - 26s 1s/step - loss: 2.2751 - accuracy: 0.3676 - val_loss: 2.3439 - val_accuracy: 0.4375
# Epoch 7/50
# 21/21 [==============================] - 27s 1s/step - loss: 2.0198 - accuracy: 0.5038 - val_loss: 2.1256 - val_accuracy: 0.5125
# Epoch 8/50
# 21/21 [==============================] - 27s 1s/step - loss: 1.9267 - accuracy: 0.5026 - val_loss: 2.2037 - val_accuracy: 0.4750
# Epoch 9/50
# 21/21 [==============================] - 26s 1s/step - loss: 1.8229 - accuracy: 0.5252 - val_loss: 2.0475 - val_accuracy: 0.4875
# Epoch 10/50
# 21/21 [==============================] - 27s 1s/step - loss: 1.5555 - accuracy: 0.5526 - val_loss: 2.0248 - val_accuracy: 0.5375
# Epoch 11/50
# 21/21 [==============================] - 27s 1s/step - loss: 1.5338 - accuracy: 0.6042 - val_loss: 1.9454 - val_accuracy: 0.5250
# Epoch 12/50
# 21/21 [==============================] - 26s 1s/step - loss: 1.5419 - accuracy: 0.5420 - val_loss: 1.7700 - val_accuracy: 0.5500
# Epoch 13/50
# 21/21 [==============================] - 27s 1s/step - loss: 1.3378 - accuracy: 0.6582 - val_loss: 1.9072 - val_accuracy: 0.4875
# Epoch 14/50
# 21/21 [==============================] - 27s 1s/step - loss: 1.4927 - accuracy: 0.5800 - val_loss: 1.8010 - val_accuracy: 0.5750
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 15/50
# 21/21 [==============================] - 28s 1s/step - loss: 1.2486 - accuracy: 0.6877 - val_loss: 1.8464 - val_accuracy: 0.5250
# Epoch 16/50
# 21/21 [==============================] - 27s 1s/step - loss: 1.0737 - accuracy: 0.7287 - val_loss: 1.7013 - val_accuracy: 0.6000
# Epoch 17/50
# 21/21 [==============================] - 27s 1s/step - loss: 1.2289 - accuracy: 0.6178 - val_loss: 1.8286 - val_accuracy: 0.5875
# Epoch 18/50
# 21/21 [==============================] - 28s 1s/step - loss: 1.1518 - accuracy: 0.7069 - val_loss: 1.9480 - val_accuracy: 0.5250
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 19/50
# 21/21 [==============================] - 26s 1s/step - loss: 1.1181 - accuracy: 0.7075 - val_loss: 1.8611 - val_accuracy: 0.5375
# Epoch 20/50
# 21/21 [==============================] - 27s 1s/step - loss: 0.9738 - accuracy: 0.7815 - val_loss: 1.9597 - val_accuracy: 0.5125
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 21/50
# 21/21 [==============================] - 28s 1s/step - loss: 1.1097 - accuracy: 0.6672 - val_loss: 1.7840 - val_accuracy: 0.5625
# Epoch 22/50
# 21/21 [==============================] - 27s 1s/step - loss: 1.1524 - accuracy: 0.6972 - val_loss: 1.8789 - val_accuracy: 0.5500
# Epoch 23/50
# 21/21 [==============================] - 27s 1s/step - loss: 1.1234 - accuracy: 0.7004 - val_loss: 1.7785 - val_accuracy: 0.6000
# Epoch 24/50
# 21/21 [==============================] - 28s 1s/step - loss: 1.1448 - accuracy: 0.6916 - val_loss: 1.7605 - val_accuracy: 0.5625
# Epoch 25/50
# 21/21 [==============================] - 27s 1s/step - loss: 1.1059 - accuracy: 0.6924 - val_loss: 1.7837 - val_accuracy: 0.6125
# Epoch 26/50
# 21/21 [==============================] - 27s 1s/step - loss: 1.0500 - accuracy: 0.7377 - val_loss: 1.7281 - val_accuracy: 0.6000
# Epoch 27/50
# 21/21 [==============================] - 28s 1s/step - loss: 1.0500 - accuracy: 0.7236 - val_loss: 1.7346 - val_accuracy: 0.5625
# Epoch 28/50
# 21/21 [==============================] - 28s 1s/step - loss: 1.0990 - accuracy: 0.6876 - val_loss: 1.7402 - val_accuracy: 0.5375
# Epoch 29/50
# 21/21 [==============================] - 28s 1s/step - loss: 1.1095 - accuracy: 0.7098 - val_loss: 1.7754 - val_accuracy: 0.5375
# Epoch 30/50
# 21/21 [==============================] - 27s 1s/step - loss: 1.0813 - accuracy: 0.7432 - val_loss: 1.7544 - val_accuracy: 0.5625
# Epoch 31/50
# 21/21 [==============================] - 28s 1s/step - loss: 1.1053 - accuracy: 0.6973 - val_loss: 1.9362 - val_accuracy: 0.5875
# Epoch 32/50
# 21/21 [==============================] - 28s 1s/step - loss: 1.1258 - accuracy: 0.7096 - val_loss: 1.7891 - val_accuracy: 0.5500
# Epoch 33/50
# 21/21 [==============================] - 28s 1s/step - loss: 1.1150 - accuracy: 0.6929 - val_loss: 1.7754 - val_accuracy: 0.5625
# Epoch 34/50
# 21/21 [==============================] - 28s 1s/step - loss: 1.0441 - accuracy: 0.7350 - val_loss: 1.7801 - val_accuracy: 0.5750
# Epoch 35/50
# 21/21 [==============================] - 28s 1s/step - loss: 1.1992 - accuracy: 0.6861 - val_loss: 1.7840 - val_accuracy: 0.5750
# Epoch 36/50
# 21/21 [==============================] - 28s 1s/step - loss: 1.2031 - accuracy: 0.6925 - val_loss: 1.7275 - val_accuracy: 0.5875
# Epoch 37/50
# 21/21 [==============================] - 27s 1s/step - loss: 0.9036 - accuracy: 0.7923 - val_loss: 1.6498 - val_accuracy: 0.6000
# Epoch 38/50
# 21/21 [==============================] - 28s 1s/step - loss: 1.0945 - accuracy: 0.7422 - val_loss: 1.8080 - val_accuracy: 0.5750
# Epoch 39/50
# 21/21 [==============================] - 27s 1s/step - loss: 1.2121 - accuracy: 0.6419 - val_loss: 1.8622 - val_accuracy: 0.5500
# Epoch 40/50
# 21/21 [==============================] - 27s 1s/step - loss: 1.1112 - accuracy: 0.7180 - val_loss: 1.7421 - val_accuracy: 0.5625
# Epoch 41/50
# 21/21 [==============================] - 28s 1s/step - loss: 1.0344 - accuracy: 0.7163 - val_loss: 1.9100 - val_accuracy: 0.5750
# Epoch 42/50
# 21/21 [==============================] - 28s 1s/step - loss: 1.0108 - accuracy: 0.7189 - val_loss: 1.8293 - val_accuracy: 0.5375
# Epoch 43/50
# 21/21 [==============================] - 27s 1s/step - loss: 1.0121 - accuracy: 0.7520 - val_loss: 1.8740 - val_accuracy: 0.5625
# Epoch 44/50
# 21/21 [==============================] - 27s 1s/step - loss: 1.0425 - accuracy: 0.7196 - val_loss: 1.7747 - val_accuracy: 0.5250
# Epoch 45/50
# 21/21 [==============================] - 27s 1s/step - loss: 1.0880 - accuracy: 0.7229 - val_loss: 1.7674 - val_accuracy: 0.6000
# Epoch 46/50
# 21/21 [==============================] - 27s 1s/step - loss: 0.9724 - accuracy: 0.7458 - val_loss: 1.8254 - val_accuracy: 0.5375
# Epoch 47/50
# 21/21 [==============================] - 27s 1s/step - loss: 1.0861 - accuracy: 0.6913 - val_loss: 1.8859 - val_accuracy: 0.5250
# Epoch 48/50
# 21/21 [==============================] - 27s 1s/step - loss: 1.0471 - accuracy: 0.7020 - val_loss: 1.8303 - val_accuracy: 0.5750
# Epoch 49/50
# 21/21 [==============================] - 28s 1s/step - loss: 1.0495 - accuracy: 0.7338 - val_loss: 1.8836 - val_accuracy: 0.5500
# Epoch 50/50
# 21/21 [==============================] - 28s 1s/step - loss: 1.0407 - accuracy: 0.7410 - val_loss: 1.6645 - val_accuracy: 0.6125

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(h.history['accuracy'], 'o-', label='train accuracy')
plt.plot(h.history['val_accuracy'], 'o-', label = 'validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(loc='lower right')

plt.subplot(1,2,2)
plt.plot(h.history['loss'], 'o-', label='train loss')
plt.plot(h.history['val_loss'], 'o-', label='validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend(loc='upper right')

plt.show()
